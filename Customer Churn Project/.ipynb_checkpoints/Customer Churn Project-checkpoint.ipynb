# %%
# program to predict Customer Churn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# read csv file
df = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/DSData/master/Telecom_customer_churn.csv')
df.columns = df.columns.str.replace(' ','_')
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
# check size of dataset
df.shape
# Out:
# (7043, 21)

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
# check for any null values
sns.heatmap(df.isnull())
plt.title('Null Values')
plt.show()

# %%
# summing up total null values in dataset
df.isnull().sum().sum()
# Out:
# 0

# %%
# getting all column names to observe type of variables
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
# show all columns at once to observe data properly
pd.set_option('max_columns', None)
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# 0              No  No phone service             DSL             No
# ...

# %%
df['MultipleLines'].value_counts()
# Out:
# No                  3390
# Yes                 2971
# No phone service     682
# Name: MultipleLines, dtype: int64

# %%
df['Contract'].value_counts()
# Out:
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: Contract, dtype: int64

# %%
df['PaymentMethod'].value_counts()
# Out:
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: PaymentMethod, dtype: int64

# %%
# deleting all columns which are insignificant to making prediction model
df = df.drop(['customerID','PaperlessBilling','TotalCharges'], axis=1)

# %%
# replacing a value with its similar kind to decrease variables
df.MultipleLines.replace(['No phone service'], ['No'], inplace=True)

# %%
df
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#      MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0               No             DSL             No          Yes
# ...

# %%
# summing up total null values in dataset again
df.isnull().sum().sum()
# Out:
# 0

# %%
# encoding string type data to use them in plotting and making model on basis of observations
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
df['gender'] = LE.fit_transform(df['gender'])

# %%
LE2 = LabelEncoder()
df['Partner'] = LE2.fit_transform(df['Partner'])

# %%
LE3 = LabelEncoder()
df['Dependents'] = LE3.fit_transform(df['Dependents'])

# %%
LE4 = LabelEncoder()
df['PhoneService'] = LE4.fit_transform(df['PhoneService'])

# %%
LE5 = LabelEncoder()
df['MultipleLines'] = LE5.fit_transform(df['MultipleLines'])

# %%
LE6 = LabelEncoder()
df['InternetService'] = LE6.fit_transform(df['InternetService'])

# %%
LE7 = LabelEncoder()
df['OnlineSecurity'] = LE7.fit_transform(df['OnlineSecurity'])

# %%
LE8 = LabelEncoder()
df['OnlineBackup'] = LE8.fit_transform(df['OnlineBackup'])

# %%
LE9 = LabelEncoder()
df['DeviceProtection'] = LE9.fit_transform(df['DeviceProtection'])

# %%
LE10 = LabelEncoder()
df['TechSupport'] = LE10.fit_transform(df['TechSupport'])

# %%
LE11 = LabelEncoder()
df['StreamingTV'] = LE11.fit_transform(df['StreamingTV'])

# %%
LE12 = LabelEncoder()
df['StreamingMovies'] = LE12.fit_transform(df['StreamingMovies'])

# %%
LE13 = LabelEncoder()
df['Contract'] = LE13.fit_transform(df['Contract'])

# %%
LE14 = LabelEncoder()
df['PaymentMethod'] = LE14.fit_transform(df['PaymentMethod'])

# %%
LE15 = LabelEncoder()
df['Churn'] = LE15.fit_transform(df['Churn'])

# %%
#crosscheck
LE.inverse_transform([0,1])
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
#crosscheck
LE14.inverse_transform(df['PaymentMethod'])
# Out:
# array(['Electronic check', 'Mailed check', 'Mailed check', ...,
#        'Electronic check', 'Mailed check', 'Bank transfer (automatic)'],
#       dtype=object)

# %%
df.corr()
# Out:
#                     gender  SeniorCitizen   Partner  Dependents    tenure  \
# gender            1.000000      -0.001874 -0.001808    0.010517  0.005106
# SeniorCitizen    -0.001874       1.000000  0.016479   -0.211185  0.016567
# Partner          -0.001808       0.016479  1.000000    0.452676  0.379697
# Dependents        0.010517      -0.211185  0.452676    1.000000  0.159712
# tenure            0.005106       0.016567  0.379697    0.159712  1.000000
# PhoneService     -0.006488       0.008576  0.017706   -0.001762  0.008448
# MultipleLines    -0.008414       0.142948  0.142057   -0.024526  0.331941
# InternetService  -0.000863      -0.032310  0.000891    0.044590 -0.030359
# OnlineSecurity   -0.015017      -0.128221  0.150828    0.152166  0.325468
# OnlineBackup     -0.012057      -0.013632  0.153130    0.091015  0.370876
# DeviceProtection  0.000549      -0.021398  0.166330    0.080537  0.371105
# TechSupport      -0.006825      -0.151268  0.126733    0.133524  0.322942
# ...

# %%
# checking corelation
corr_mat = df.corr()
plt.figure(figsize=(22,7))
sns.heatmap(corr_mat,annot=True,linewidths=0.1,linecolor='black',fmt='0.2f')
# Out:
# <AxesSubplot:>

# %%
# plotting density of values in each column
import warnings
plt.figure(figsize=(15,20),facecolor='white')
plotnumber = 1

for column in df:
    if plotnumber<=17:
        ax = plt.subplot(5,4,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=10)
    plotnumber+=1
plt.tight_layout()
# Out:
# C:\Users\Vageesh\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Vageesh\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Preprocessing
# spliting dependent and independent variables on x and y axis
x = df.drop('Churn',axis=1)
y = df['Churn']

# %%
x
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0          0              0        1           0       1             0
# 1          1              0        0           0      34             1
# 2          1              0        0           0       2             1
# 3          1              0        0           0      45             0
# 4          0              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038       1              0        1           1      24             1
# 7039       0              0        1           1      72             1
# 7040       0              0        1           1      11             0
# 7041       1              1        1           0       4             1
# 7042       1              0        0           0      66             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# ...

# %%
y
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 7038    0
# 7039    0
# 7040    0
# 7041    1
# 7042    0
# Name: Churn, Length: 7043, dtype: int32

# %%
x.dtypes
# Out:
# gender                int32
# SeniorCitizen         int64
# Partner               int32
# Dependents            int32
# tenure                int64
# PhoneService          int32
# MultipleLines         int32
# InternetService       int32
# OnlineSecurity        int32
# OnlineBackup          int32
# DeviceProtection      int32
# TechSupport           int32
# StreamingTV           int32
# StreamingMovies       int32
# Contract              int32
# PaymentMethod         int32
# MonthlyCharges      float64
# dtype: object

# %%
# making scatter plot of Income vs other independent variables in dataset for observations
plt.figure(figsize=(15,20),facecolor='white')
plotnumber = 1

for column in x:
    if plotnumber<=17:
        ax = plt.subplot(5,4,plotnumber)
        plt.scatter(x[column],y)
        plt.xlabel(column,fontsize=10)
        plt.ylabel('Churn',fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %%
# use Random Forest to make model for Income prediction
from sklearn.model_selection import train_test_split
import seaborn as sns
import pickle

import warnings
warnings.filterwarnings('ignore')

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=45)
y_train.head()
# Out:
# 6154    0
# 5108    0
# 619     0
# 3784    1
# 600     0
# Name: Churn, dtype: int32

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators= 101, n_jobs=-1)
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=101, n_jobs=-1)

# %%
y_pred = rf.predict(x_test)

# %%
# find accuracy of predictions made by comparing to test sample
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.7967064168086314

# %%
# save model in pickle file
import pickle
filename= 'Customer_Churn_model.pickle'
pickle.dump(RandomForestClassifier,open(filename,'wb'))
