# %%
# program to predict Next Day Rainfall and Rainfall value
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# read csv file
df = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset3/main/weatherAUS.csv')
df.columns = df.columns.str.replace(' ','_')
df
# Out:
#             Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1     2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2     2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3     2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4     2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# ...          ...      ...      ...      ...       ...          ...       ...
# 8420  2017-06-21    Uluru      2.8     23.4       0.0          NaN       NaN
# 8421  2017-06-22    Uluru      3.6     25.3       0.0          NaN       NaN
# 8422  2017-06-23    Uluru      5.4     26.9       0.0          NaN       NaN
# 8423  2017-06-24    Uluru      7.8     27.0       0.0          NaN       NaN
# 8424  2017-06-25    Uluru     14.9      NaN       0.0          NaN       NaN
#
# ...

# %%
# check size of dataset
df.shape
# Out:
# (8425, 23)

# %%
df.describe()
# Out:
#            MinTemp      MaxTemp     Rainfall  Evaporation     Sunshine  \
# count  8350.000000  8365.000000  8185.000000  4913.000000  4431.000000
# mean     13.193305    23.859976     2.805913     5.389395     7.632205
# std       5.403596     6.136408    10.459379     5.044484     3.896235
# min      -2.000000     8.200000     0.000000     0.000000     0.000000
# 25%       9.200000    19.300000     0.000000     2.600000     4.750000
# 50%      13.300000    23.300000     0.000000     4.600000     8.700000
# 75%      17.400000    28.000000     1.000000     7.000000    10.700000
# max      28.500000    45.500000   371.000000   145.000000    13.900000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count    7434.000000   8349.000000   8318.000000  8366.000000  8323.000000
# mean       40.174469     13.847646     18.533662    67.822496    51.249790
# std        14.665721     10.174579      9.766986    16.833283    18.423774
# ...

# %%
# check for any null values
sns.heatmap(df.isnull())
plt.title('Null Values')
plt.show()

# %%
# summing up total null values in dataset
df.isnull().sum()
# Out:
# Date                0
# Location            0
# MinTemp            75
# MaxTemp            60
# Rainfall          240
# Evaporation      3512
# Sunshine         3994
# WindGustDir       991
# WindGustSpeed     991
# WindDir9am        829
# WindDir3pm        308
# WindSpeed9am       76
# WindSpeed3pm      107
# Humidity9am        59
# Humidity3pm       102
# Pressure9am      1309
# Pressure3pm      1312
# Cloud9am         2421
# Cloud3pm         2455
# Temp9am            56
# Temp3pm            96
# RainToday         240
# RainTomorrow      239
# dtype: int64

# %%
# getting all column names to observe type of variables
df.columns
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#        'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RainTomorrow'],
#       dtype='object')

# %%
df['Location'].value_counts()
# Out:
# Melbourne       1622
# Williamtown     1230
# PerthAirport    1204
# Albury           907
# Newcastle        822
# CoffsHarbour     611
# Brisbane         579
# Penrith          482
# Wollongong       474
# Darwin           250
# Adelaide         205
# Uluru             39
# Name: Location, dtype: int64

# %%
df['Evaporation'].value_counts()
# Out:
# 4.0     180
# 3.0     163
# 2.4     147
# 2.2     146
# 2.6     143
#        ...
# 17.0      1
# 18.6      1
# 22.4      1
# 19.2      1
# 0.7       1
# Name: Evaporation, Length: 116, dtype: int64

# %%
df['Sunshine'].value_counts()
# Out:
# 0.0     166
# 11.1     68
# 11.2     67
# 11.0     66
# 10.7     64
#        ...
# 2.5       8
# 13.6      7
# 13.8      4
# 13.9      3
# 13.5      2
# Name: Sunshine, Length: 140, dtype: int64

# %%
df['RainToday'].value_counts()
# Out:
# No     6195
# Yes    1990
# Name: RainToday, dtype: int64

# %%
df['RainTomorrow'].value_counts()
# Out:
# No     6195
# Yes    1991
# Name: RainTomorrow, dtype: int64

# %%
df.corr()
# Out:
#                 MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# MinTemp        1.000000  0.720955  0.091642     0.348643  0.081365
# MaxTemp        0.720955  1.000000 -0.088906     0.424728  0.523909
# Rainfall       0.091642 -0.088906  1.000000     0.043463 -0.209654
# Evaporation    0.348643  0.424728  0.043463     1.000000  0.340893
# Sunshine       0.081365  0.523909 -0.209654     0.340893  1.000000
# WindGustSpeed  0.241317  0.146113  0.104999     0.214069 -0.018455
# WindSpeed9am   0.137263  0.013425  0.051349     0.176701 -0.025112
# WindSpeed3pm   0.180091  0.088797  0.025185     0.142421  0.045031
# Humidity9am   -0.130906 -0.392496  0.231702    -0.286869 -0.512349
# Humidity3pm    0.079569 -0.424217  0.238730    -0.221244 -0.630536
# Pressure9am   -0.465478 -0.347285 -0.080412    -0.218171  0.028666
# Pressure3pm   -0.458665 -0.430074 -0.037270    -0.233401 -0.047098
# Cloud9am       0.111213 -0.307700  0.195157    -0.084288 -0.705577
# ...

# %%
# checking corelation
corr_mat = df.corr()
plt.figure(figsize=(22,7))
sns.heatmap(corr_mat,annot=True,linewidths=0.1,linecolor='black',fmt='0.2f')
# Out:
# <AxesSubplot:>

# %%
# deleting all columns which are insignificant to making prediction model
df = df.drop(['MinTemp','MaxTemp','Date'], axis=1)

# %%
df
# Out:
#      Location  Rainfall  Evaporation  Sunshine WindGustDir  WindGustSpeed  \
# 0      Albury       0.6          NaN       NaN           W           44.0
# 1      Albury       0.0          NaN       NaN         WNW           44.0
# 2      Albury       0.0          NaN       NaN         WSW           46.0
# 3      Albury       0.0          NaN       NaN          NE           24.0
# 4      Albury       1.0          NaN       NaN           W           41.0
# ...       ...       ...          ...       ...         ...            ...
# 8420    Uluru       0.0          NaN       NaN           E           31.0
# 8421    Uluru       0.0          NaN       NaN         NNW           22.0
# 8422    Uluru       0.0          NaN       NaN           N           37.0
# 8423    Uluru       0.0          NaN       NaN          SE           28.0
# 8424    Uluru       0.0          NaN       NaN         NaN            NaN
#
#      WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  \
# ...

# %%
# filling null values in dependants column by using 'ffill' method
df['Evaporation'].fillna(method ='ffill', inplace = True)

# %%
df['Sunshine'].fillna(method ='ffill', inplace = True)

# %%
df['Cloud3pm'].fillna(method ='ffill', inplace = True)

# %%
df['Cloud9am'].fillna(method ='ffill', inplace = True)

# %%
# deleting records with null values as columns with most null values are now okay
df = df.dropna()
df = df.reset_index()

# %%
df = df.drop(['index'], axis=1)

# %%
df
# Out:
#           Location  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0     CoffsHarbour      24.4          8.6       9.0         ESE
# 1     CoffsHarbour       6.8          3.8       3.4           E
# 2     CoffsHarbour      16.8          2.8       6.1         WSW
# 3     CoffsHarbour       0.0          3.2      11.0         ENE
# 4     CoffsHarbour       0.0          6.8       9.0         NNE
# ...            ...       ...          ...       ...         ...
# 5630         Uluru       0.0          5.6       8.6           E
# 5631         Uluru       0.0          5.6       8.6           E
# 5632         Uluru       0.0          5.6       8.6         NNW
# 5633         Uluru       0.0          5.6       8.6           N
# 5634         Uluru       0.0          5.6       8.6          SE
#
#       WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  \
# 0              35.0         SW        ESE          17.0          22.0
# ...

# %%
# encoding string type data to use them in plotting and making model on basis of observations
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
df['Location'] = LE.fit_transform(df['Location'])

# %%
LE2 = LabelEncoder()
df['WindGustDir'] = LE2.fit_transform(df['WindGustDir'])

# %%
LE3 = LabelEncoder()
df['WindDir9am'] = LE3.fit_transform(df['WindDir9am'])

# %%
LE4 = LabelEncoder()
df['WindDir3pm'] = LE4.fit_transform(df['WindDir3pm'])

# %%
LE5 = LabelEncoder()
df['RainToday'] = LE5.fit_transform(df['RainToday'])

# %%
LE6 = LabelEncoder()
df['RainTomorrow'] = LE6.fit_transform(df['RainTomorrow'])

# %%
# checking corelation
corr_mat = df.corr()
plt.figure(figsize=(22,7))
sns.heatmap(corr_mat,annot=True,linewidths=0.1,linecolor='black',fmt='0.2f')
# Out:
# <AxesSubplot:>

# %%
#crosscheck
LE.inverse_transform([0,1,2,3,4,5])
# Out:
# array(['Adelaide', 'Brisbane', 'CoffsHarbour', 'Darwin', 'Melbourne',
#        'PerthAirport'], dtype=object)

# %%
#crosscheck
LE2.inverse_transform(df['WindGustDir'])
# Out:
# array(['ESE', 'E', 'WSW', ..., 'NNW', 'N', 'SE'], dtype=object)

# %%
# plotting density of values in each column
import warnings
plt.figure(figsize=(15,20),facecolor='white')
plotnumber = 1

for column in df:
    if plotnumber<=19:
        ax = plt.subplot(5,4,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=10)
    plotnumber+=1
plt.tight_layout()
# Out:
# C:\Users\Vageesh\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Vageesh\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Preprocessing
# spliting dependent and independent variables on x and y axis
x = df.drop('RainToday',axis=1)
y = df['RainToday']

# %%
x
# Out:
#       Location  Rainfall  Evaporation  Sunshine  WindGustDir  WindGustSpeed  \
# 0            2      24.4          8.6       9.0            2           35.0
# 1            2       6.8          3.8       3.4            0           33.0
# 2            2      16.8          2.8       6.1           15           19.0
# 3            2       0.0          3.2      11.0            1           30.0
# 4            2       0.0          6.8       9.0            5           50.0
# ...        ...       ...          ...       ...          ...            ...
# 5630         6       0.0          5.6       8.6            0           31.0
# 5631         6       0.0          5.6       8.6            0           31.0
# 5632         6       0.0          5.6       8.6            6           22.0
# 5633         6       0.0          5.6       8.6            3           37.0
# 5634         6       0.0          5.6       8.6            9           28.0
#
# ...

# %%
y
# Out:
# 0       1
# 1       1
# 2       1
# 3       0
# 4       0
#        ..
# 5630    0
# 5631    0
# 5632    0
# 5633    0
# 5634    0
# Name: RainToday, Length: 5635, dtype: int32

# %%
x.dtypes
# Out:
# Location           int32
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir        int32
# WindGustSpeed    float64
# WindDir9am         int32
# WindDir3pm         int32
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainTomorrow       int32
# dtype: object

# %%
# making scatter plot of Income vs other independent variables in dataset for observations
plt.figure(figsize=(15,20),facecolor='white')
plotnumber = 1

for column in x:
    if plotnumber<=10:
        ax = plt.subplot(4,4,plotnumber)
        plt.scatter(x[column],y)
        plt.xlabel(column,fontsize=10)
        plt.ylabel('Rain_Tomorrow',fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %%
# use Random Forest to make model for Income prediction
from sklearn.model_selection import train_test_split
import seaborn as sns
import pickle

import warnings
warnings.filterwarnings('ignore')

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30,random_state=60)
y_train.head()
# Out:
# 5254    0
# 132     0
# 2569    1
# 1918    0
# 3287    0
# Name: RainToday, dtype: int32

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators= 101, n_jobs=-1)
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=101, n_jobs=-1)

# %%
y_pred = rf.predict(x_test)

# %%
# find accuracy of predictions made by comparing to test sample
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
# save model in pickle file
import pickle
filename= 'Rainfall_Prediction_model.pickle'
pickle.dump(RandomForestClassifier,open(filename,'wb'))

# %%
# now for rainfall value prediction we will make separate dataset split
x1 = df.drop('Rainfall',axis=1)
y1 = df['Rainfall']

# %%
x1
# Out:
#       Location  Evaporation  Sunshine  WindGustDir  WindGustSpeed  WindDir9am  \
# 0            2          8.6       9.0            2           35.0          12
# 1            2          3.8       3.4            0           33.0          12
# 2            2          2.8       6.1           15           19.0          15
# 3            2          3.2      11.0            1           30.0          12
# 4            2          6.8       9.0            5           50.0           6
# ...        ...          ...       ...          ...            ...         ...
# 5630         6          5.6       8.6            0           31.0           2
# 5631         6          5.6       8.6            0           31.0           9
# 5632         6          5.6       8.6            6           22.0           9
# 5633         6          5.6       8.6            3           37.0           9
# 5634         6          5.6       8.6            9           28.0          10
#
# ...

# %%
y1
# Out:
# 0       24.4
# 1        6.8
# 2       16.8
# 3        0.0
# 4        0.0
#         ...
# 5630     0.0
# 5631     0.0
# 5632     0.0
# 5633     0.0
# 5634     0.0
# Name: Rainfall, Length: 5635, dtype: float64

# %%
from sklearn.model_selection import train_test_split
import seaborn as sns
import pickle

import warnings
warnings.filterwarnings('ignore')

x1_train,x1_test,y1_train,y1_test = train_test_split(x1,y1,test_size=0.25,random_state=70)
y1_train.head()
# Out:
# 2241    0.0
# 4605    0.0
# 2237    0.0
# 1822    4.2
# 4147    0.0
# Name: Rainfall, dtype: float64

# %%
# using Linear Regression to train model
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
import seaborn as sns
import pickle

import warnings
warnings.filterwarnings('ignore')
l_reg = LinearRegression()
l_reg.fit(x1_train,y1_train)
# Out:
# LinearRegression()

# %%
y1_pred = l_reg.predict(x1_test)

# %%
y1_pred
# Out:
# array([ 0.97729938, -3.07829387,  0.46338507, ...,  1.72994864,
#         0.51433006,  0.6599213 ])

# %%
plt.scatter(y1_test,y1_pred)
plt.xlabel('Actual Status')
plt.ylabel('Predicted Status')
plt.title('Rainfall Actual vs Prediction')
plt.show()

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
mean_absolute_error(y1_test,y1_pred)
# Out:
# 3.266432834421657

# %%
#saving model
import pickle
filename= 'rainfall_model.pickle'
pickle.dump(l_reg,open(filename,'wb'))
